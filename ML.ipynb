# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
x_train=np.array([5,10,15,20,25,30])
y_train=np.array([15,25,35,45,55,65])
x_test=np.array([])
y_test=np.array([])

print("x_train :",x_train)
print("y_train :",y_train)
# Out:
# x_train : [ 5 10 15 20 25 30]
# y_train : [15 25 35 45 55 65]

# %%
# Generate  the random values 
import random
m = [random.randint(-50, 50) for i in range(1000)]
print(m)
c = [random.randint(-50, 50) for i in range(1000)]
print(c)
# Out:
# [-33, 31, -15, -37, 3, 24, 34, -38, 45, 16, 20, -43, -21, -43, 45, -47, -11, 28, -28, -47, -2, 18, 41, 43, 27, 23, 9, -43, -25, 23, 32, 20, 2, -42, -20, -10, -48, -3, -33, -43, 8, -32, -44, -39, -35, -23, -1, 35, -46, 28, -16, 24, -10, -16, -38, -36, 0, -18, 47, -29, -6, -32, -50, -43, -27, -19, -36, 10, -12, 36, -10, -20, -23, 30, -9, -16, 27, -17, -11, -42, 14, 30, -18, 1, 3, 13, 8, -13, -40, 46, 26, 35, -21, -35, 38, 33, -13, 44, -40, 30, -32, -42, 17, 26, -11, 7, -26, -7, -28, -31, 17, -27, -37, 47, -9, -46, -8, 30, 10, -32, -42, -45, 46, -15, -7, 50, -4, -49, -2, 2, -3, -28, 41, 48, 45, -26, 46, 34, 3, -29, -19, 41, -24, 31, 42, 26, 12, -19, -47, -15, 43, 23, 26, 46, 3, -44, -32, -19, -24, -37, 13, 21, -43, -46, -32, 24, 23, 10, 28, 5, -16, 14, 28, -44, 13, -42, -19, 18, 5, 8, 21, -30, -2, 25, -41, -42, 29, 31, 6, -25, -41, -16, 31, -33, -50, 6, -36, 25, -21, -28, 46, -28, 1, 43, -34, -18, -35, 17, 15, -13, -8, 12, 21, 29, 44, 22, 15, 38, 42, -19, -31, 17, -46, 31, -15, 20, -11,
# ...

# %%
plt.scatter(m, c,c='c')
plt.title("Plot")
plt.ylabel('m')
plt.xlabel('c')
# Out:
# Text(0.5, 0, 'c')

# %%
# Plot the data points
plt.scatter(x_train, y_train,c='c')
plt.title("Plot")
plt.ylabel('Y')
plt.xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %%
# define prediction
def compute_model_prediction(x, m, c):
    n = x.shape[0]
    f_wb = np.zeros(n)
    for i in range(n):
        f_wb[i] = m * x[i] + c
        
    return f_wb

# define cost funtion

def compute_cost(x, y, m, c): 
    n = x.shape[0] 
    
    cost_sum = 0 
    for i in range(n): 
        f_wb = m * x[i] + c   
        cost = (f_wb - y[i]) ** 2  
        cost_sum = cost_sum + cost  
    total_cost = (1 / (2 * n)) * cost_sum  

    return total_cost

# %%
temp_m=[]
for i in m:
  temp_m.append(compute_model_prediction(x_train, i, 0))

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='c',label='Actual Values')
plt.scatter(x_train, y_train,c='b')
plt.title("Plot")
plt.ylabel('Y')
plt.xlabel('X')


# plot the prediction
for i in range(len(temp_m)):
  plt.plot(x_train, temp_m[i], c='r',label='Prediction')                     
                  
plt.show()

# %%
# cost funtion for each m
temp_jmc=[]
for i in m:
  temp_jmc.append(compute_cost(x_train, y_train, i, 0))
print(temp_jmc)
# Out:
# [235314.5833333333, 156914.5833333333, 56289.58333333333, 291781.25, 114.58333333333333, 89845.83333333333, 191345.8333333333, 306845.8333333333, 346789.5833333333, 35945.83333333333, 59862.5, 387856.25, 102314.58333333333, 387856.25, 346789.5833333333, 459489.5833333333, 33189.58333333333, 125895.83333333333, 173262.5, 459489.5833333333, 3395.833333333333, 47145.83333333333, 284956.25, 315114.5833333333, 116314.58333333333, 81781.25, 8689.583333333332, 387856.25, 140581.25, 81781.25, 168012.5, 59862.5, 12.5, 370895.8333333333, 93695.83333333333, 28362.5, 478345.8333333333, 5189.583333333333, 235314.5833333333, 387856.25, 6312.5, 222145.8333333333, 405195.8333333333, 322289.5833333333, 262789.5833333333, 120689.58333333333, 1981.25, 203581.25, 441012.5, 125895.83333333333, 63012.5, 89845.83333333333, 28362.5, 63012.5, 306845.8333333333, 277095.8333333333, 945.8333333333333, 77595.83333333333, 379981.25, 184914.5833333333, 12845.833333333332, 222145.8333333333, 517195.8333333333, 3878
# ...

# %%
plt.plot(m,temp_jmc,c='b')
plt.title("cost funtion")
plt.ylabel('j(m)')
plt.xlabel('m')
# Out:
# Text(0.5, 0, 'm')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(m, c, temp_jmc , c='r', marker='o')

# Adding labels to the x, y, and z axis
ax.set_xlabel('m')

ax.set_ylabel('c')
ax.set_zlabel('temp_jmc')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

plt.plot(m, c, 'r*')
plt.axis([0, 6, 0, 20])

for i, j,k in zip(m, c,temp_jmc):
  if k==min(temp_jmc):
    plt.text(i, j+0.5, '({}, {}, {})'.format(i, j,k))

plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
bOf_fmc=[]
for i,j,k in zip(m, c,temp_jmc):
  if k==min(temp_jmc):
    bOf_fmc.append(j)
print(bOf_fmc)
# Out:
# [-1, 29, -36, 23, -4, -2, -18, -45, 14, 38, -43]

# %%
#find cost

final_m=2
cost=[]
for c in bOf_fmc:
    cost.append(compute_cost(x_train, y_train, final_m, c))
print('cost:',cost)

#find c for minimum cost

final_c=bOf_fmc[cost.index(min(cost))]

print("C :",final_c)
# Out:
# cost: [18.0, 288.0, 840.5, 162.0, 40.5, 24.5, 264.5, 1250.0, 40.5, 544.5, 1152.0]
# C : -1

# %%
def model(x):
    y=final_m*x+final_c
    return y

# %%
# Testing
y=model(80)
print('Y:',y)
# Out:
# Y: 159
